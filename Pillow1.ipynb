# %% [markdown]
# <a href="https://colab.research.google.com/github/aist1110-2020R1/lecture9/blob/main/Pillow1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Demonstrate some image processing using Pillow and NumPy.

# %%
import numpy as np

# %%
from IPython.display import display
from PIL import Image

# read an image
image = Image.open("sample-images/lena.jpg")

# show the image
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x225 at 0x7FC650B5AEF0>

# %%
im = np.array(image)
im

# %%
im.shape

# %% [markdown]
# Convert to grayscale image:

# %%
g = image.convert('L')
display(g)

im_gray = np.array(g)
print(im_gray.ndim)
print(im_gray.shape)

# %% [markdown]
# Gamma correction:

# %%
im = np.array(Image.open('sample-images/lenna.jpg').resize((256, 256)))
im_1_22 = 255.0 * (im / 255.0) ** (1 / 2.2)
im_22   = 255.0 * (im / 255.0) ** 2.2
im_gamma = np.concatenate((im_1_22, im, im_22), axis=1)
pil_img = Image.fromarray(np.uint8(im_gamma))
display(pil_img)

# %%
image = Image.open('sample-images/lenna.jpg').resize((256, 256))
display(image)

# %% [markdown]
# Rotate and flip:

# %%
im = np.array(image)
im_rot90 = np.rot90(im)

pil_img = Image.fromarray(np.uint8(im_rot90))
display(pil_img)

# %%
im = np.array(image)
im_fliplr = np.fliplr(im)

pil_img = Image.fromarray(np.uint8(im_fliplr))
display(pil_img)
